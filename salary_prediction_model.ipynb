# %% [markdown]
# # Understanding Data

# %%
# Importing necessary dependecies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Ignores future warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Reading Data from a csv and creating a dataframe
data = pd.read_csv(r"/content/survey_results_public.csv")
df = pd.DataFrame(data)

# %%
# Looking at a few instances of the data
df.head(20)
# Out:
#     ResponseId     Q120                                         MainBranch  \
# 0            1  I agree                                      None of these
# 1            2  I agree                     I am a developer by profession
# 2            3  I agree                     I am a developer by profession
# 3            4  I agree                     I am a developer by profession
# 4            5  I agree                     I am a developer by profession
# 5            6  I agree                     I am a developer by profession
# 6            7  I agree                     I am a developer by profession
# 7            8  I agree                     I am a developer by profession
# 8            9  I agree  I am not primarily a developer, but I write co...
# 9           10  I agree                     I am a developer by profession
# 10          11  I agree                     I am a developer by profession
# 11          12  I agree                     I am a developer by profession
# 12          13  I agree                     I am a developer by profession
# 13          14  I agree  I am not primarily a developer, but I write co...
# 14          15  I agree                     I am a developer by profession
# 15          16  I agree                     I am a developer by profession
# 16          17  I agree                     I am a developer by profession
# 17          18  I agree                     I am a developer by profession
# 18          19  I agree                     I am a developer by profession
# 19          20  I agree                     I am a developer by profession
#
#                    Age                                         Employment  \
# 0      18-24 years old                                                NaN
# 1      25-34 years old                                Employed, full-time
# 2      45-54 years old                                Employed, full-time
# 3      25-34 years old                                Employed, full-time
# 4      25-34 years old  Employed, full-time;Independent contractor, fr...
# 5      35-44 years old                                Employed, full-time
# 6      35-44 years old                                Employed, full-time
# 7      25-34 years old                                Employed, full-time
# 8      45-54 years old                                Employed, full-time
# 9      25-34 years old                 Not employed, but looking for work
# 10     25-34 years old                                Employed, full-time
# 11     25-34 years old                                Employed, full-time
# 12     25-34 years old                                Employed, full-time
# 13     35-44 years old                                Employed, full-time
# 14     25-34 years old                                Employed, full-time
# 15     35-44 years old                                Employed, full-time
# 16     35-44 years old                                Employed, full-time
# 17     25-34 years old                                Employed, full-time
# 18  Under 18 years old                                Employed, full-time
# 19     35-44 years old                                Employed, full-time
#
#                               RemoteWork  \
# 0                                    NaN
# 1                                 Remote
# 2   Hybrid (some remote, some in-person)
# 3   Hybrid (some remote, some in-person)
# 4                                 Remote
# 5                                 Remote
# 6                                 Remote
# 7                                 Remote
# 8   Hybrid (some remote, some in-person)
# 9                                    NaN
# 10                                Remote
# 11                                Remote
# 12                                Remote
# 13  Hybrid (some remote, some in-person)
# 14  Hybrid (some remote, some in-person)
# 15  Hybrid (some remote, some in-person)
# 16  Hybrid (some remote, some in-person)
# 17  Hybrid (some remote, some in-person)
# 18                                Remote
# 19  Hybrid (some remote, some in-person)
#
#                                      CodingActivities  \
# 0                                                 NaN
# 1   Hobby;Contribute to open-source projects;Boots...
# 2   Hobby;Professional development or self-paced l...
# 3                                               Hobby
# 4   Hobby;Contribute to open-source projects;Profe...
# 5   Hobby;Professional development or self-paced l...
# 6   Hobby;Contribute to open-source projects;Profe...
# 7                                               Hobby
# 8            Hobby;Contribute to open-source projects
# 9                                                 NaN
# 10                                              Hobby
# 11                                              Hobby
# 12  Hobby;Professional development or self-paced l...
# 13  Hobby;Professional development or self-paced l...
# 14                                              Hobby
# 15  Hobby;Contribute to open-source projects;Profe...
# 16                                              Hobby
# 17                                              Hobby
# 18                 Contribute to open-source projects
# 19  Hobby;Professional development or self-paced l...
#
#                                               EdLevel  \
# 0                                                 NaN
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5   Some college/university study without earning ...
# 6   Some college/university study without earning ...
# 7        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 13    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 14    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 16       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 17    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 18                          Primary/elementary school
# 19  Some college/university study without earning ...
#
#                                             LearnCode  \
# 0                                                 NaN
# 1   Books / Physical media;Colleague;Friend or fam...
# 2   Books / Physical media;Colleague;On the job tr...
# 3   Colleague;Friend or family member;Other online...
# 4   Books / Physical media;Online Courses or Certi...
# 5   Books / Physical media;Colleague;Online Course...
# 6   Friend or family member;Online Courses or Cert...
# 7   Books / Physical media;Online Courses or Certi...
# 8   Online Courses or Certification;On the job tra...
# 9   Books / Physical media;Online Courses or Certi...
# 10  Books / Physical media;Friend or family member...
# 11  Online Courses or Certification;Other online r...
# 12  Online Courses or Certification;Other online r...
# 13  Books / Physical media;Online Courses or Certi...
# 14  On the job training;Other online resources (e....
# 15  Books / Physical media;Other online resources ...
# 16    Online Courses or Certification;Coding Bootcamp
# 17  Books / Physical media;Colleague;Other online ...
# 18                             Books / Physical media
# 19  Online Courses or Certification;On the job tra...
#
#                                       LearnCodeOnline  ...        Frequency_1  \
# 0                                                 NaN  ...                NaN
# 1   Formal documentation provided by the owner of ...  ...   1-2 times a week
# 2   Formal documentation provided by the owner of ...  ...  6-10 times a week
# 3   Formal documentation provided by the owner of ...  ...   1-2 times a week
# 4   Formal documentation provided by the owner of ...  ...   1-2 times a week
# 5   Formal documentation provided by the owner of ...  ...   1-2 times a week
# 6                                                 NaN  ...   1-2 times a week
# 7   Formal documentation provided by the owner of ...  ...                NaN
# 8   Formal documentation provided by the owner of ...  ...                NaN
# 9   Formal documentation provided by the owner of ...  ...                NaN
# 10  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 11  Formal documentation provided by the owner of ...  ...                NaN
# 12  Blogs with tips and tricks;Books;How-to videos...  ...              Never
# 13  Blogs with tips and tricks;Books;Video-based O...  ...   1-2 times a week
# 14  Formal documentation provided by the owner of ...  ...              Never
# 15  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 16                                                NaN  ...                NaN
# 17  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 18                                                NaN  ...                NaN
# 19  Formal documentation provided by the owner of ...  ...   1-2 times a week
#
#           Frequency_2        Frequency_3               TimeSearching  \
# 0                 NaN                NaN                         NaN
# 1    10+ times a week              Never         15-30 minutes a day
# 2   6-10 times a week   3-5 times a week         30-60 minutes a day
# 3    10+ times a week   1-2 times a week         15-30 minutes a day
# 4    1-2 times a week   3-5 times a week        60-120 minutes a day
# 5    1-2 times a week   3-5 times a week         30-60 minutes a day
# 6    3-5 times a week   1-2 times a week  Less than 15 minutes a day
# 7                 NaN                NaN        60-120 minutes a day
# 8                 NaN                NaN                         NaN
# 9                 NaN                NaN                         NaN
# 10   1-2 times a week  6-10 times a week         30-60 minutes a day
# 11                NaN                NaN                         NaN
# 12   3-5 times a week              Never         15-30 minutes a day
# 13   3-5 times a week   3-5 times a week         15-30 minutes a day
# 14  6-10 times a week   1-2 times a week         15-30 minutes a day
# 15   1-2 times a week   1-2 times a week         15-30 minutes a day
# 16                NaN                NaN                         NaN
# 17   1-2 times a week   1-2 times a week        60-120 minutes a day
# 18                NaN                NaN                         NaN
# 19   3-5 times a week   1-2 times a week         15-30 minutes a day
#
#              TimeAnswering                                   ProfessionalTech  \
# 0                      NaN                                                NaN
# 1      15-30 minutes a day  DevOps function;Microservices;Automated testin...
# 2      30-60 minutes a day  DevOps function;Microservices;Automated testin...
# 3      30-60 minutes a day  Automated testing;Continuous integration (CI) ...
# 4      30-60 minutes a day  Microservices;Automated testing;Observability ...
# 5      15-30 minutes a day  DevOps function;Microservices;Observability to...
# 6      15-30 minutes a day  Microservices;Automated testing;Continuous int...
# 7      30-60 minutes a day                                      None of these
# 8                      NaN                                                NaN
# 9                      NaN                                                NaN
# 10    60-120 minutes a day  Automated testing;Continuous integration (CI) ...
# 11                     NaN                                                NaN
# 12     15-30 minutes a day  Automated testing;Observability tools;Continuo...
# 13     30-60 minutes a day  Automated testing;Observability tools;Continuo...
# 14  Over 120 minutes a day  Microservices;Observability tools;Developer po...
# 15     15-30 minutes a day  Microservices;Automated testing;Observability ...
# 16                     NaN                                                NaN
# 17     30-60 minutes a day  DevOps function;Microservices;Automated testin...
# 18                     NaN                                                NaN
# 19     15-30 minutes a day  Observability tools;Continuous integration (CI...
#
#                                              Industry           SurveyLength  \
# 0                                                 NaN                    NaN
# 1   Information Services, IT, Software Development...  Appropriate in length
# 2   Information Services, IT, Software Development...  Appropriate in length
# 3                                                 NaN  Appropriate in length
# 4                                               Other  Appropriate in length
# 5                                               Other  Appropriate in length
# 6   Information Services, IT, Software Development...  Appropriate in length
# 7                                  Financial Services                    NaN
# 8                                                 NaN  Appropriate in length
# 9                                                 NaN  Appropriate in length
# 10                                              Other  Appropriate in length
# 11                                                NaN  Appropriate in length
# 12                                              Other  Appropriate in length
# 13  Information Services, IT, Software Development...  Appropriate in length
# 14                                              Other  Appropriate in length
# 15     Manufacturing, Transportation, or Supply Chain               Too long
# 16                                                NaN  Appropriate in length
# 17                       Retail and Consumer Services  Appropriate in length
# 18                                                NaN                    NaN
# 19  Information Services, IT, Software Development...  Appropriate in length
#
#                     SurveyEase ConvertedCompYearly
# 0                          NaN                 NaN
# 1                         Easy            285000.0
# 2                         Easy            250000.0
# 3                         Easy            156000.0
# 4   Neither easy nor difficult             23456.0
# 5   Neither easy nor difficult             96828.0
# 6                         Easy            135000.0
# 7                          NaN             80000.0
# 8   Neither easy nor difficult             64254.0
# 9   Neither easy nor difficult                 NaN
# 10  Neither easy nor difficult                 NaN
# 11                        Easy             78003.0
# 12                        Easy             75000.0
# 13                        Easy            150000.0
# 14                        Easy            187407.0
# 15  Neither easy nor difficult            107090.0
# 16                        Easy             45149.0
# 17                        Easy             58899.0
# 18                         NaN                14.0
# 19                        Easy             75010.0
#
# [20 rows x 84 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2365 entries, 0 to 2364
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           2365 non-null   int64
#  1   Q120                                 2365 non-null   object
#  2   MainBranch                           2365 non-null   object
#  3   Age                                  2365 non-null   object
#  4   Employment                           2348 non-null   object
#  5   RemoteWork                           1999 non-null   object
#  6   CodingActivities                     1996 non-null   object
#  7   EdLevel                              2350 non-null   object
#  8   LearnCode                            2341 non-null   object
#  9   LearnCodeOnline                      1855 non-null   object
#  10  LearnCodeCoursesCert                 945 non-null    object
#  11  YearsCode                            2337 non-null   object
#  12  YearsCodePro                         1808 non-null   object
#  13  DevType                              2069 non-null   object
#  14  OrgSize                              1788 non-null   object
#  15  PurchaseInfluence                    1782 non-null   object
#  16  TechList                             1615 non-null   object
#  17  BuyNewTool                           2205 non-null   object
#  18  Country                              2350 non-null   object
#  19  Currency                             1794 non-null   object
#  20  CompTotal                            1267 non-null   float64
#  21  LanguageHaveWorkedWith               2324 non-null   object
#  22  LanguageWantToWorkWith               2176 non-null   object
#  23  DatabaseHaveWorkedWith               1985 non-null   object
#  24  DatabaseWantToWorkWith               1670 non-null   object
#  25  PlatformHaveWorkedWith               1640 non-null   object
#  26  PlatformWantToWorkWith               1335 non-null   object
#  27  WebframeHaveWorkedWith               1806 non-null   object
#  28  WebframeWantToWorkWith               1543 non-null   object
#  29  MiscTechHaveWorkedWith               1618 non-null   object
#  30  MiscTechWantToWorkWith               1360 non-null   object
#  31  ToolsTechHaveWorkedWith              2083 non-null   object
#  32  ToolsTechWantToWorkWith              1846 non-null   object
#  33  NEWCollabToolsHaveWorkedWith         2271 non-null   object
#  34  NEWCollabToolsWantToWorkWith         2038 non-null   object
#  35  OpSysPersonal use                    2318 non-null   object
#  36  OpSysProfessional use                2100 non-null   object
#  37  OfficeStackAsyncHaveWorkedWith       1822 non-null   object
#  38  OfficeStackAsyncWantToWorkWith       1437 non-null   object
#  39  OfficeStackSyncHaveWorkedWith        2222 non-null   object
#  40  OfficeStackSyncWantToWorkWith        1863 non-null   object
#  41  AISearchHaveWorkedWith               1411 non-null   object
#  42  AISearchWantToWorkWith               1116 non-null   object
#  43  AIDevHaveWorkedWith                  567 non-null    object
#  44  AIDevWantToWorkWith                  413 non-null    object
#  45  NEWSOSites                           2350 non-null   object
#  46  SOVisitFreq                          2343 non-null   object
#  47  SOAccount                            2349 non-null   object
#  48  SOPartFreq                           2108 non-null   object
#  49  SOComm                               2346 non-null   object
#  50  SOAI                                 1387 non-null   object
#  51  AISelect                             2350 non-null   object
#  52  AISent                               1480 non-null   object
#  53  AIAcc                                917 non-null    object
#  54  AIBen                                1477 non-null   object
#  55  AIToolInterested in Using            762 non-null    object
#  56  AIToolCurrently Using                832 non-null    object
#  57  AIToolNot interested in Using        501 non-null    object
#  58  AINextVery different                 216 non-null    object
#  59  AINextNeither different nor similar  155 non-null    object
#  60  AINextSomewhat similar               145 non-null    object
#  61  AINextVery similar                   69 non-null     object
#  62  AINextSomewhat different             467 non-null    object
#  63  TBranch                              1798 non-null   object
#  64  ICorPM                               1258 non-null   object
#  65  WorkExp                              1259 non-null   float64
#  66  Knowledge_1                          1221 non-null   object
#  67  Knowledge_2                          1195 non-null   object
#  68  Knowledge_3                          1197 non-null   object
#  69  Knowledge_4                          1196 non-null   object
#  70  Knowledge_5                          1189 non-null   object
#  71  Knowledge_6                          1194 non-null   object
#  72  Knowledge_7                          1194 non-null   object
#  73  Knowledge_8                          1182 non-null   object
#  74  Frequency_1                          1203 non-null   object
#  75  Frequency_2                          1199 non-null   object
#  76  Frequency_3                          1170 non-null   object
#  77  TimeSearching                        1233 non-null   object
#  78  TimeAnswering                        1228 non-null   object
#  79  ProfessionalTech                     1193 non-null   object
#  80  Industry                             1077 non-null   object
#  81  SurveyLength                         2317 non-null   object
#  82  SurveyEase                           2321 non-null   object
#  83  ConvertedCompYearly                  1261 non-null   float64
# dtypes: float64(3), int64(1), object(80)
# memory usage: 1.5+ MB

# %%
# Get stats for numerical attributes
df.describe()
# Out:
#         ResponseId     CompTotal      WorkExp  ConvertedCompYearly
# count  2365.000000  1.267000e+03  1259.000000         1.261000e+03
# mean   1183.000000  2.031574e+07    11.230342         9.084371e+04
# std     682.861016  2.947612e+08     8.631900         2.604009e+05
# min       1.000000  0.000000e+00     0.000000         1.000000e+00
# 25%     592.000000  5.500000e+04     5.000000         4.240700e+04
# 50%    1183.000000  9.500000e+04     9.000000         7.067900e+04
# 75%    1774.000000  1.821000e+05    15.000000         1.100000e+05
# max    2365.000000  7.000000e+09    48.000000         9.000000e+06

# %%
# Looking for correlations
df[["CompTotal", "WorkExp", "ConvertedCompYearly"]].corr()
# Out:
#                      CompTotal   WorkExp  ConvertedCompYearly
# CompTotal             1.000000 -0.034983             0.004285
# WorkExp              -0.034983  1.000000             0.052006
# ConvertedCompYearly   0.004285  0.052006             1.000000

# %%
df.hist(figsize=(19,10))
# Out:
# array([[<Axes: title={'center': 'ResponseId'}>,
#         <Axes: title={'center': 'CompTotal'}>],
#        [<Axes: title={'center': 'WorkExp'}>,
#         <Axes: title={'center': 'ConvertedCompYearly'}>]], dtype=object)

# %%
# Creating a scatterplot to show the correlation between different numerical attributes
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(19,10), grid=True, diagonal="hist",)
# Out:
# array([[<Axes: xlabel='ResponseId', ylabel='ResponseId'>,
#         <Axes: xlabel='CompTotal', ylabel='ResponseId'>,
#         <Axes: xlabel='WorkExp', ylabel='ResponseId'>,
#         <Axes: xlabel='ConvertedCompYearly', ylabel='ResponseId'>],
#        [<Axes: xlabel='ResponseId', ylabel='CompTotal'>,
#         <Axes: xlabel='CompTotal', ylabel='CompTotal'>,
#         <Axes: xlabel='WorkExp', ylabel='CompTotal'>,
#         <Axes: xlabel='ConvertedCompYearly', ylabel='CompTotal'>],
#        [<Axes: xlabel='ResponseId', ylabel='WorkExp'>,
#         <Axes: xlabel='CompTotal', ylabel='WorkExp'>,
#         <Axes: xlabel='WorkExp', ylabel='WorkExp'>,
#         <Axes: xlabel='ConvertedCompYearly', ylabel='WorkExp'>],
#        [<Axes: xlabel='ResponseId', ylabel='ConvertedCompYearly'>,
#         <Axes: xlabel='CompTotal', ylabel='ConvertedCompYearly'>,
#         <Axes: xlabel='WorkExp', ylabel='ConvertedCompYearly'>,
#         <Axes: xlabel='ConvertedCompYearly', ylabel='ConvertedCompYearly'>]],
#       dtype=object)

# %% [markdown]
# # Data Preprocessing

# %%
# Dropping unecessary columns
df.drop(["ResponseId", "Q120", "MainBranch", "LearnCode", "LearnCodeOnline",
                "LearnCodeCoursesCert", "PurchaseInfluence", "TechList",
                "BuyNewTool", "LanguageWantToWorkWith", "DatabaseWantToWorkWith", "PlatformWantToWorkWith",
                "WebframeWantToWorkWith", "MiscTechWantToWorkWith", "ToolsTechWantToWorkWith", "NEWCollabToolsHaveWorkedWith",
                "NEWCollabToolsWantToWorkWith", "OpSysPersonal use", "OpSysProfessional use", "OfficeStackAsyncHaveWorkedWith",
                "OfficeStackAsyncWantToWorkWith", "OfficeStackSyncHaveWorkedWith", "OfficeStackSyncWantToWorkWith", "AISearchHaveWorkedWith",
                "AISearchWantToWorkWith", "AIDevHaveWorkedWith", "AIDevWantToWorkWith", "NEWSOSites", "SOVisitFreq", "SOAccount", "SOPartFreq",
                "SOComm", "SOAI", "AISelect", "AISent", "AIAcc", "AIBen", "AIToolInterested in Using", "AIToolCurrently Using", "AIToolNot interested in Using",
                "AINextVery different", "AINextNeither different nor similar", "AINextSomewhat similar", "AINextVery similar", "AINextSomewhat different", "TBranch",
                "ICorPM", "Knowledge_1", "Knowledge_2", "Knowledge_3", "Knowledge_4", "Knowledge_5", "Knowledge_6", "Knowledge_7", "Knowledge_8",
                "Frequency_1", "Frequency_2", "Frequency_3", "TimeSearching", "TimeAnswering", "SurveyLength", "SurveyEase", "Currency", "CompTotal","CodingActivities"], inplace=True, axis=1)

# %%
# Dropping missing values
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                 Age           Employment  \
# 1   25-34 years old  Employed, full-time
# 6   35-44 years old  Employed, full-time
# 7   25-34 years old  Employed, full-time
# 15  35-44 years old  Employed, full-time
# 19  35-44 years old  Employed, full-time
#
#                               RemoteWork  \
# 1                                 Remote
# 6                                 Remote
# 7                                 Remote
# 15  Hybrid (some remote, some in-person)
# 19  Hybrid (some remote, some in-person)
#
#                                               EdLevel YearsCode YearsCodePro  \
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)        18            9
# 6   Some college/university study without earning ...         4            3
# 7        Bachelor’s degree (B.A., B.S., B.Eng., etc.)         5            3
# 15    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        15           10
# 19  Some college/university study without earning ...        24           14
#
#                                  DevType                   OrgSize  \
# 1   Senior Executive (C-Suite, VP, etc.)          2 to 9 employees
# 6                  Developer, full-stack  1,000 to 4,999 employees
# 7                  Developer, full-stack        10 to 19 employees
# 15                   Developer, back-end      100 to 499 employees
# 19                 Developer, full-stack        20 to 99 employees
#
#                      Country  \
# 1   United States of America
# 6   United States of America
# 7   United States of America
# 15                   Germany
# 19                   Germany
#
#                                LanguageHaveWorkedWith  \
# 1                          HTML/CSS;JavaScript;Python
# 6   Ada;Clojure;Elixir;Go;HTML/CSS;Java;JavaScript...
# 7   Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 15  Bash/Shell (all shells);Dart;Go;Haskell;HTML/C...
# 19                         Java;JavaScript;TypeScript
#
#                                DatabaseHaveWorkedWith  \
# 1                                            Supabase
# 6   MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 7                 Dynamodb;MongoDB;MySQL;Redis;SQLite
# 15  Cassandra;Dynamodb;Elasticsearch;H2;MariaDB;Mo...
# 19                                 MariaDB;PostgreSQL
#
#                                PlatformHaveWorkedWith  \
# 1            Amazon Web Services (AWS);Netlify;Vercel
# 6             Amazon Web Services (AWS);Digital Ocean
# 7     Amazon Web Services (AWS);Fly.io;Netlify;Vercel
# 15          Amazon Web Services (AWS);Microsoft Azure
# 19  Amazon Web Services (AWS);Digital Ocean;Hetzne...
#
#                                WebframeHaveWorkedWith  \
# 1                          Next.js;React;Remix;Vue.js
# 6   AngularJS;jQuery;Node.js;Phoenix;Ruby on Rails...
# 7               Angular;Express;Next.js;Node.js;React
# 15                        Angular;Express;Spring Boot
# 19                            Angular;Express;Node.js
#
#                             MiscTechHaveWorkedWith  \
# 1                      Electron;React Native;Tauri
# 6                        RabbitMQ;Spring Framework
# 7       NumPy;Pandas;Scikit-Learn;Tauri;TensorFlow
# 15  Apache Kafka;Flutter;RabbitMQ;Spring Framework
# 19                                Spring Framework
#
#                               ToolsTechHaveWorkedWith  WorkExp  \
# 1         Docker;Kubernetes;npm;Pip;Vite;Webpack;Yarn     10.0
# 6   Bun;Cargo;Chocolatey;Docker;Homebrew;Kubernete...      4.0
# 7   Ansible;Cargo;Docker;Homebrew;Make;npm;Pip;pnp...      5.0
# 15  Ansible;Ant;Docker;Gradle;Kubernetes;Make;Mave...     15.0
# 19            Docker;Gradle;npm;Podman;Terraform;Vite     14.0
#
#                                      ProfessionalTech  \
# 1   DevOps function;Microservices;Automated testin...
# 6   Microservices;Automated testing;Continuous int...
# 7                                       None of these
# 15  Microservices;Automated testing;Observability ...
# 19  Observability tools;Continuous integration (CI...
#
#                                              Industry  ConvertedCompYearly
# 1   Information Services, IT, Software Development...             285000.0
# 6   Information Services, IT, Software Development...             135000.0
# 7                                  Financial Services              80000.0
# 15     Manufacturing, Transportation, or Supply Chain             107090.0
# 19  Information Services, IT, Software Development...              75010.0

# %%
# Converting necessary columns into numerical
df["YearsCode"] = pd.to_numeric(df["YearsCode"].replace("Less than 1 year", 0).replace("More than 50 years", 50))
df["YearsCodePro"] = pd.to_numeric(df["YearsCode"].replace("Less than 1 year", 0).replace("More than 50 years", 50))
df["WorkExp"] = pd.to_numeric(df["WorkExp"])

# %%
# Converting necessary columns into categorical
def turn_to_cat(cols:list):
    for col in cols:
        df[col] = df[col].astype("category")

turn_to_cat(["Age", "Employment", "RemoteWork", "EdLevel", "DevType", "OrgSize", "Country", "Industry"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 372 entries, 1 to 2360
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      372 non-null    category
#  1   Employment               372 non-null    category
#  2   RemoteWork               372 non-null    category
#  3   EdLevel                  372 non-null    category
#  4   YearsCode                372 non-null    int64
#  5   YearsCodePro             372 non-null    int64
#  6   DevType                  372 non-null    category
#  7   OrgSize                  372 non-null    category
#  8   Country                  372 non-null    category
#  9   LanguageHaveWorkedWith   372 non-null    object
#  10  DatabaseHaveWorkedWith   372 non-null    object
#  11  PlatformHaveWorkedWith   372 non-null    object
#  12  WebframeHaveWorkedWith   372 non-null    object
#  13  MiscTechHaveWorkedWith   372 non-null    object
#  14  ToolsTechHaveWorkedWith  372 non-null    object
#  15  WorkExp                  372 non-null    float64
#  16  ProfessionalTech         372 non-null    object
#  17  Industry                 372 non-null    category
#  18  ConvertedCompYearly      372 non-null    float64
# dtypes: category(8), float64(2), int64(2), object(7)
# memory usage: 42.8+ KB

# %% [markdown]
# # Feature Engineering

# %%
# Feature engineering
df["NumberOfLanguages"] = df["LanguageHaveWorkedWith"].str.split(";").apply(len)
df["NumberOfPlatforms"] = df["PlatformHaveWorkedWith"].str.split(";").apply(len)
df["NumberOfWebframe"] = df["WebframeHaveWorkedWith"].str.split(";").apply(len)
df["NumberOfMiscTech"] = df["MiscTechHaveWorkedWith"].str.split(";").apply(len)
df["NumberOfToolsTech"] = df["ToolsTechHaveWorkedWith"].str.split(";").apply(len)
df["NumberOfDatabases"] = df["DatabaseHaveWorkedWith"].str.split(";").apply(len)

# %%
# Dropping columns
df.drop(["LanguageHaveWorkedWith", "PlatformHaveWorkedWith", "WebframeHaveWorkedWith",
         "MiscTechHaveWorkedWith", "ToolsTechHaveWorkedWith", "DatabaseHaveWorkedWith"], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 372 entries, 1 to 2360
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  372 non-null    category
#  1   Employment           372 non-null    category
#  2   RemoteWork           372 non-null    category
#  3   EdLevel              372 non-null    category
#  4   YearsCode            372 non-null    int64
#  5   YearsCodePro         372 non-null    int64
#  6   DevType              372 non-null    category
#  7   OrgSize              372 non-null    category
#  8   Country              372 non-null    category
#  9   WorkExp              372 non-null    float64
#  10  ProfessionalTech     372 non-null    object
#  11  Industry             372 non-null    category
#  12  ConvertedCompYearly  372 non-null    float64
#  13  NumberOfLanguages    372 non-null    int64
#  14  NumberOfPlatforms    372 non-null    int64
#  15  NumberOfWebframe     372 non-null    int64
#  16  NumberOfMiscTech     372 non-null    int64
#  17  NumberOfToolsTech    372 non-null    int64
#  18  NumberOfDatabases    372 non-null    int64
# dtypes: category(8), float64(2), int64(8), object(1)
# memory usage: 42.8+ KB

# %%
# Binning the target value
df["ConvertedCompYearly_binned"] = pd.qcut(df["ConvertedCompYearly"], q=10, duplicates="drop")

# %%
# Applying different encoding techniques on various columns
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler

# Defining which columns are which
numerical_columns = ["YearsCode", "YearsCodePro", "WorkExp", "NumberOfLanguages", "NumberOfPlatforms",
                     "NumberOfWebframe", "NumberOfMiscTech", "NumberOfToolsTech", "NumberOfDatabases"]
ordinal_cols = ["Age", "EdLevel", "OrgSize"]
one_hot_cols = ["Employment", "RemoteWork", "DevType", "Country", "ProfessionalTech", "Industry"]

# Encoding relevant columns
preprocessing = ColumnTransformer([
    ("num", "passthrough", ["YearsCode", "YearsCodePro", "WorkExp","NumberOfLanguages", "NumberOfPlatforms",
                     "NumberOfWebframe", "NumberOfMiscTech", "NumberOfToolsTech", "NumberOfDatabases"]),

    ("ord_cols_age", OrdinalEncoder(categories=[["Under 18 years old","18-24 years old","25-34 years old","35-44 years old",
                                                "45-54 years old","55-64 years old","65 years or older","Prefer not to say"]]), ["Age"]),

    ("ord_cols_edlvl", OrdinalEncoder(categories=[["Primary/elementary school","Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)",
                                                  "Some college/university study without earning a degree","Associate degree (A.A., A.S., etc.)","Bachelor’s degree (B.A., B.S., B.Eng., etc.)",
                                                  "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)","Professional degree (JD, MD, Ph.D, Ed.D, etc.)","Something else"]]), ["EdLevel"]),

    ("ord_cols_orgsize", OrdinalEncoder(categories=[["Just me - I am a freelancer, sole proprietor, etc.","2 to 9 employees","10 to 19 employees","20 to 99 employees","100 to 499 employees",
                                                    "500 to 999 employees","1,000 to 4,999 employees","5,000 to 9,999 employees","10,000 or more employees","I don’t know"]]), ["OrgSize"]),

    ("one_hot_cols", OneHotEncoder(handle_unknown="ignore", sparse_output=False), ["Employment", "RemoteWork", "DevType", "Country", "ProfessionalTech", "Industry"])
], remainder="passthrough")

# Creating features and labels
X = df.drop(columns=["ConvertedCompYearly", "ConvertedCompYearly_binned"])
y = np.log1p(df["ConvertedCompYearly"]) # Ensuring that the target value distribution is not skewed

# Splitting the data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=df["ConvertedCompYearly_binned"],test_size=0.2, random_state=42)

# Dropping the stratified column
df.drop(columns=["ConvertedCompYearly_binned"], inplace=True)

# Creating a pipeline
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("lin_reg", LinearRegression())
])

# %% [markdown]
# # Analyzing With Models

# %%
# Fitting the pipeline to the linear regression model (Training)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', 'passthrough',
#                                                   ['YearsCode', 'YearsCodePro',
#                                                    'WorkExp',
#                                                    'NumberOfLanguages',
#                                                    'NumberOfPlatforms',
#                                                    'NumberOfWebframe',
#                                                    'NumberOfMiscTech',
#                                                    'NumberOfToolsTech',
#                                                    'NumberOfDatabases']),
#                                                  ('ord_cols_age',
#                                                   OrdinalEncoder(categories=[['Under '
#                                                                               '18 '
#                                                                               'years '
#                                                                               'old',
#                                                                               '18-24 '
#                                                                               'years '
#                                                                               '...
#                                                                               'employees',
#                                                                               '1,000 '
#                                                                               'to '
#                                                                               '4,999 '
#                                                                               'employees',
#                                                                               '5,000 '
#                                                                               'to '
#                                                                               '9,999 '
#                                                                               'employees',
#                                                                               '10,000 '
#                                                                               'or '
#                                                                               'more '
#                                                                               'employees',
#                                                                               'I '
#                                                                               'don’t '
#                                                                               'know']]),
#                                                   ['OrgSize']),
#                                                  ('one_hot_cols',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Employment', 'RemoteWork',
#                                                    'DevType', 'Country',
#                                                    'ProfessionalTech',
#                                                    'Industry'])])),
#                 ('scaler', StandardScaler()), ('lin_reg', LinearRegression())])

# %%
# Using the model to predict
y_predictions = pipeline.predict(X_test)

# %%
# Evaluating the model
from sklearn.metrics import root_mean_squared_error, mean_absolute_error

rmse = root_mean_squared_error(y_test, y_predictions)
mae = mean_absolute_error(y_test, y_predictions)
print(f"RMSE: {rmse:,.4f}")
print(f"MAE: {mae:,.4f}")
# Out:
# RMSE: 1.2931
# MAE: 1.0120

# %%
# Overfitting check
y_train_pred = pipeline.predict(X_train)
y_train_rmse = root_mean_squared_error(y_train, y_train_pred)

y_test_pred = pipeline.predict(X_test)
y_test_rmse = root_mean_squared_error(y_test, y_test_pred)

print(f"Train RMSE: {y_train_rmse:,.4f}")
print(f"Test RMSE: {y_test_rmse:,.4f}")
print(f"Train MAE: {mean_absolute_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test MAE: {mean_absolute_error(y_test, pipeline.predict(X_test)):,.4f}")
# Out:
# Train RMSE: 0.5156
# Test RMSE: 1.2931
# Train MAE: 0.3038
# Test MAE: 1.0120

# %% [markdown]
# <font size="2">The Linear model is overfitting<font>

# %% [markdown]
# Trying different models

# %%
# Using a Decision Tree regressor as our model
from sklearn.tree import DecisionTreeRegressor

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("decision_tree", DecisionTreeRegressor(random_state=42))
])


pipeline.fit(X_train, y_train) # Training the decision tree
print(f"Train RMSE: {root_mean_squared_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test RMSE: {root_mean_squared_error(y_test, pipeline.predict(X_test)):,.4f}")
print(f"Train MAE: {mean_absolute_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test MAE: {mean_absolute_error(y_test, pipeline.predict(X_test)):,.4f}")
# Out:
# Train RMSE: 0.0000
# Test RMSE: 1.0398
# Train MAE: 0.0000
# Test MAE: 0.6628

# %% [markdown]
# We will use MAE as our evaluation metric since we want to find the average error

# %%
# Using a Random Forest regressor as our model
from sklearn.ensemble import RandomForestRegressor

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("random_forest", RandomForestRegressor(n_estimators=10, random_state=42))
])


pipeline.fit(X_train, y_train) # Training the Random forest
print(f"Train RMSE: {root_mean_squared_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test RMSE: {root_mean_squared_error(y_test, pipeline.predict(X_test)):,.4f}")
print(f"Train MAE: {mean_absolute_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test MAE: {mean_absolute_error(y_test, pipeline.predict(X_test)):,.4f}")
# Out:
# Train RMSE: 0.4229
# Test RMSE: 0.7337
# Train MAE: 0.2539
# Test MAE: 0.4880

# %%
# Using XGBoost as our model
import xgboost as xgb

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("xgboost", xgb.XGBRegressor(n_estimators=10, random_state=42, learning_rate=0.3))
])


pipeline.fit(X_train, y_train) # Training the XGBoost
print(f"Train RMSE: {root_mean_squared_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test RMSE: {root_mean_squared_error(y_test, pipeline.predict(X_test)):,.4f}")
print(f"Train MAE: {mean_absolute_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test MAE: {mean_absolute_error(y_test, pipeline.predict(X_test)):,.4f}")
# Out:
# Train RMSE: 0.4598
# Test RMSE: 0.7512
# Train MAE: 0.3095
# Test MAE: 0.4736

# %%
# Using LightGBM

import lightgbm as lgb

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("lightgbm", lgb.LGBMRegressor(n_estimators=10, random_state=42, learning_rate=0.3, verbose=-1))
])


pipeline.fit(X_train, y_train) # Training the LightGBM
print(f"Train RMSE: {root_mean_squared_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test RMSE: {root_mean_squared_error(y_test, pipeline.predict(X_test)):,.4f}")
print(f"Train MAE: {mean_absolute_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test MAE: {mean_absolute_error(y_test, pipeline.predict(X_test)):,.4f}")
# Out:
# Train RMSE: 0.8073
# Test RMSE: 0.8182
# Train MAE: 0.4910
# Test MAE: 0.5657

# %%
from catboost import CatBoostRegressor

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("catboost", CatBoostRegressor(iterations=10, learning_rate=0.3, depth=6, random_state=42))
])


pipeline.fit(X_train, y_train) # Training the decision tree
print(f"Train RMSE: {root_mean_squared_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test RMSE: {root_mean_squared_error(y_test, pipeline.predict(X_test)):,.4f}")
print(f"Train MAE: {mean_absolute_error(y_train, pipeline.predict(X_train)):,.4f}")
print(f"Test MAE: {mean_absolute_error(y_test, pipeline.predict(X_test)):,.4f}")
# Out:
# 0:	learn: 1.1447900	total: 51.3ms	remaining: 461ms
# 1:	learn: 1.0797750	total: 53.6ms	remaining: 214ms
# 2:	learn: 1.0496781	total: 55.1ms	remaining: 129ms
# 3:	learn: 1.0114646	total: 60.9ms	remaining: 91.4ms
# 4:	learn: 0.9685653	total: 71.7ms	remaining: 71.7ms
# 5:	learn: 0.9430952	total: 73.2ms	remaining: 48.8ms
# 6:	learn: 0.9024952	total: 79.8ms	remaining: 34.2ms
# 7:	learn: 0.8793137	total: 91ms	remaining: 22.7ms
# 8:	learn: 0.8586124	total: 92.9ms	remaining: 10.3ms
# 9:	learn: 0.8397320	total: 105ms	remaining: 0us
# Train RMSE: 0.8397
# Test RMSE: 0.7686
# Train MAE: 0.5467
# Test MAE: 0.5082

# %% [markdown]
# To make sure that our models were not lucky, we will use cross-validation

# %%
# cross validating the linear model
from sklearn.model_selection import cross_val_score

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("lin_reg", LinearRegression())
])

lin_reg_cross_val_scores = cross_val_score(pipeline, X, y, scoring="neg_mean_absolute_error", cv=5)
print(f"CV Scores: {-lin_reg_cross_val_scores}")
print(f"Average CV score: {-lin_reg_cross_val_scores.mean():,.2f}")
# Out:
# CV Scores: [0.94396312 0.93751993 0.77540823 0.92492909 0.81229469]
# Average CV score: 0.88

# %%
# cross validating the Decision Tree model
pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("decision_tree", DecisionTreeRegressor(random_state=42))
])

decision_tree_cross_val_scores = cross_val_score(pipeline, X, y, scoring="neg_mean_absolute_error", cv=5)
print(f"CV Scores: {-decision_tree_cross_val_scores}")
print(f"Average CV score: {-decision_tree_cross_val_scores.mean():,.2f}")
# Out:
# CV Scores: [0.95654316 0.83601367 0.73135152 0.89255816 0.69088171]
# Average CV score: 0.82

# %%
# cross validating the Random Forest model
pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("random_forest", RandomForestRegressor(n_estimators=10, random_state=42))
])

random_forest_cross_val_scores = cross_val_score(pipeline, X, y, scoring="neg_mean_absolute_error", cv=5)
print(f"CV Scores: {-random_forest_cross_val_scores}")
print(f"Average CV score: {-random_forest_cross_val_scores.mean():,.2f}")
# Out:
# CV Scores: [0.63235227 0.63590993 0.54967819 0.63380886 0.53541466]
# Average CV score: 0.60

# %%
# cross validating the XGBoost model
pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("xgboost", xgb.XGBRegressor(n_estimators=10, random_state=42, learning_rate=0.3))
])

xgboost_cross_val_scores = cross_val_score(pipeline, X, y, scoring="neg_mean_absolute_error", cv=5)
print(f"CV Scores: {-xgboost_cross_val_scores}")
print(f"Average CV score: {-xgboost_cross_val_scores.mean():,.2f}")
# Out:
# CV Scores: [0.72641546 0.61561939 0.52317321 0.63357561 0.563802  ]
# Average CV score: 0.61

# %%
# cross validating the LightGBM model
pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("lgb_reg", lgb.LGBMRegressor(n_estimators=10, random_state=42, learning_rate=0.3, verbose=-1))
])

lgb_reg_cross_val_scores = cross_val_score(pipeline, X, y, scoring="neg_mean_absolute_error", cv=5)
print(f"CV Scores: {-random_forest_cross_val_scores}")
print(f"Average CV score: {-lgb_reg_cross_val_scores.mean():,.2f}")
# Out:
# CV Scores: [0.63235227 0.63590993 0.54967819 0.63380886 0.53541466]
# Average CV score: 0.64

# %%
# cross validating the LightGBM model
pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("scaler", StandardScaler()),
    ("catboost", CatBoostRegressor(iterations=10, learning_rate=0.3, depth=6, random_state=42))
])

catboost_cross_val_scores = cross_val_score(pipeline, X, y, scoring="neg_mean_absolute_error", cv=5)
print(f"CV Scores: {-catboost_cross_val_scores}")
print(f"Average CV score: {-catboost_cross_val_scores.mean():,.2f}")
# Out:
# 0:	learn: 1.1512757	total: 1.19ms	remaining: 10.7ms
# 1:	learn: 1.0822428	total: 2.32ms	remaining: 9.27ms
# 2:	learn: 1.0241239	total: 3.31ms	remaining: 7.74ms
# 3:	learn: 0.9821817	total: 4.3ms	remaining: 6.46ms
# 4:	learn: 0.9345129	total: 5.29ms	remaining: 5.29ms
# 5:	learn: 0.9137049	total: 6.25ms	remaining: 4.17ms
# 6:	learn: 0.8863633	total: 7.23ms	remaining: 3.1ms
# 7:	learn: 0.8657357	total: 8.24ms	remaining: 2.06ms
# 8:	learn: 0.8402117	total: 9.22ms	remaining: 1.02ms
# 9:	learn: 0.8244419	total: 10.2ms	remaining: 0us
# 0:	learn: 1.1638446	total: 1.12ms	remaining: 10.1ms
# 1:	learn: 1.1018089	total: 2.14ms	remaining: 8.56ms
# 2:	learn: 1.0432411	total: 3.12ms	remaining: 7.29ms
# 3:	learn: 1.0062660	total: 4.11ms	remaining: 6.16ms
# 4:	learn: 0.9700453	total: 5.08ms	remaining: 5.08ms
# 5:	learn: 0.9413851	total: 6.04ms	remaining: 4.03ms
# 6:	learn: 0.9114591	total: 7.02ms	remaining: 3.01ms
# 7:	learn: 0.8821698	total: 8ms	remaining: 2ms
# 8:	learn: 0.8527606	total: 8.97ms	remaining: 996us
# 9:	learn: 0.8366348	total: 9.92ms	remaining: 0us
# 0:	learn: 1.1596472	total: 1.14ms	remaining: 10.2ms
# 1:	learn: 1.0983571	total: 2.15ms	remaining: 8.59ms
# 2:	learn: 1.0477448	total: 3.13ms	remaining: 7.31ms
# 3:	learn: 1.0054937	total: 4.11ms	remaining: 6.17ms
# 4:	learn: 0.9734903	total: 5.09ms	remaining: 5.09ms
# 5:	learn: 0.9486623	total: 6.12ms	remaining: 4.08ms
# 6:	learn: 0.9134811	total: 7.1ms	remaining: 3.04ms
# 7:	learn: 0.8835540	total: 8.07ms	remaining: 2.02ms
# 8:	learn: 0.8642679	total: 9.04ms	remaining: 1ms
# 9:	learn: 0.8553904	total: 10ms	remaining: 0us
# 0:	learn: 1.1036464	total: 1.09ms	remaining: 9.86ms
# 1:	learn: 1.0845678	total: 2.14ms	remaining: 8.57ms
# 2:	learn: 1.0113206	total: 3.13ms	remaining: 7.3ms
# 3:	learn: 0.9840081	total: 4.09ms	remaining: 6.14ms
# 4:	learn: 0.9445625	total: 5.05ms	remaining: 5.05ms
# 5:	learn: 0.8986897	total: 6.01ms	remaining: 4ms
# 6:	learn: 0.8684759	total: 6.96ms	remaining: 2.98ms
# 7:	learn: 0.8327707	total: 7.92ms	remaining: 1.98ms
# 8:	learn: 0.7900728	total: 8.88ms	remaining: 986us
# 9:	learn: 0.7755869	total: 9.89ms	remaining: 0us
# 0:	learn: 1.0258539	total: 1.38ms	remaining: 12.4ms
# 1:	learn: 0.9629784	total: 2.87ms	remaining: 11.5ms
# 2:	learn: 0.9348647	total: 4.11ms	remaining: 9.59ms
# 3:	learn: 0.8963825	total: 5.58ms	remaining: 8.37ms
# 4:	learn: 0.8840630	total: 6.78ms	remaining: 6.78ms
# 5:	learn: 0.8520203	total: 7.77ms	remaining: 5.18ms
# 6:	learn: 0.8340616	total: 14.5ms	remaining: 6.23ms
# 7:	learn: 0.8196357	total: 15.6ms	remaining: 3.91ms
# 8:	learn: 0.7972501	total: 16.6ms	remaining: 1.85ms
# 9:	learn: 0.7848774	total: 17.6ms	remaining: 0us
# CV Scores: [0.70193019 0.65762107 0.55646204 0.63748055 0.62004107]
# Average CV score: 0.63

# %% [markdown]
# Tuning and Testing

# %% [markdown]
# <font size="2"> The Random Forest Regressor was the most promising model, so we will tune it instead. <font>

# %%
# Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

pipeline = Pipeline([
    ("preprocessor", preprocessing),
    ("random_forest", RandomForestRegressor(n_estimators=10,random_state=42))
])

param_grid = {
      'random_forest__n_estimators': [100, 200, 300],
      'random_forest__max_depth': [5, 10, 15, None],
      'random_forest__max_features': [0.5, 'sqrt', 'log2'],
      'random_forest__min_samples_split': [5, 10, 20],
      'random_forest__min_samples_leaf': [2, 5, 10],
      'random_forest__random_state': [42]

}



random_search = RandomizedSearchCV(pipeline, param_distributions=param_grid, cv=10, random_state=42, scoring="neg_mean_absolute_error", n_iter=50)

# Fitting the model
random_search.fit(X_train, y_train)

print("Best Hyperparameters: ", random_search.best_params_)
print("Best Score: ", random_search.best_score_)

best_model = random_search.best_estimator_
# Out:
# Best Hyperparameters:  {'random_forest__n_estimators': 300, 'random_forest__min_samples_split': 5, 'random_forest__min_samples_leaf': 2, 'random_forest__max_features': 0.5, 'random_forest__max_depth': 15}
# Best Score:  -0.614576125131516

# %%
# Using our best model to make predictions
print("Train MAE: ", mean_absolute_error(y_train, best_model.predict(X_train)))
print("Test MAE: ", mean_absolute_error(y_test, best_model.predict(X_test)))
# Out:
# Train MAE:  0.35185416193988284
# Test MAE:  0.46920663619132164

# %%
# Cross validating our best model
cross_val_scores = cross_val_score(best_model, X, y, scoring="neg_mean_absolute_error", cv=10)
print(f"CV Scores: {-cross_val_scores}")
print(f"Average CV score: {-cross_val_scores.mean():,.2f}")
# Out:
# CV Scores: [0.62139142 0.67291258 0.63759762 0.5533607  0.47143553 0.60860122
#  0.67765419 0.56354495 0.43444919 0.65722361]
# Average CV score: 0.59

# %% [markdown]
# <font size="2">After tuning, the model seems to have improved <font>

# %% [markdown]
# # Visualizing Results

# %%
# Plotting actual vs predictions for our best model
plt.figure(figsize=(19,10))
plt.scatter(y_test, best_model.predict(X_test))
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted (Tuned Model)")
plt.figure(figsize=(19,10))
plt.show()
plt.savefig("actual_vs_predicted (Tuned Model).png")

# %%
# Plotting actual vs predictions for our base model
pipeline.fit(X_train, y_train)
plt.figure(figsize=(19,10))
plt.scatter(y_test, pipeline.predict(X_test))
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted (Base Model)")
plt.show()
plt.savefig("actual_vs_predicted (Base Model).png")

# %% [markdown]
# <font size="2"> The model seems to be doing okay for higher salaries but noisy in the mid-range and overpredicts on low salaries <font>

# %%
# Plotting a residuals plot
import seaborn as sns
plt.figure(figsize=(19,10))
sns.scatterplot(x=best_model.predict(X_test), y=y_test-best_model.predict(X_test))
plt.axhline(y=0, color='r', linestyle='-')

# %%
# Plotting a residuals distribution
plt.figure(figsize=(19,10))
sns.histplot(y_test-best_model.predict(X_test), kde=True, bins=30)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residuals Distribution")
plt.grid(True)
plt.show()
plt.savefig("residuals_distribution.png")

# %%
# Saving the model
import joblib
joblib.dump(best_model, "best_model.pkl")
# Out:
# ['best_model.pkl']
